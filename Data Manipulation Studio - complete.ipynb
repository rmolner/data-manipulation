# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
Baltimore_df = pd.read_csv('baltimore_9-24-2016_9-30-2017.csv')
Boston_df = pd.read_csv('boston_9-24-2016_9-30-2017.csv')
Newyork_df = pd.read_csv('new-york_9-24-2016_9-30-2017.csv')
Philadelphia_df = pd.read_csv('philadelphia_9-24-2016_9-30-2017.csv')

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
for col in Baltimore_df.columns:
    pct_missing = np.mean(Baltimore_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
Baltimore_df = Baltimore_df.drop(['Type', 'Sub Variety', 'Grade', 'Origin District', 'Color', 'Environment', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop', 'Trans Mode'], axis=1)

Baltimore_df['Variety'] = Baltimore_df['Variety'].fillna('_MISSING_')
Baltimore_df['Origin'] = Baltimore_df['Origin'].fillna('_MISSING_')
Baltimore_df['Item Size'] = Baltimore_df['Item Size'].fillna('_MISSING_')

Baltimore_df.info()

Baltimore_df.boxplot()

Baltimore_df['Item Size'].value_counts().plot.bar()

Baltimore_df.info()
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  153 non-null    object
#  1   City Name       153 non-null    object
#  2   Package         153 non-null    object
#  3   Variety         153 non-null    object
#  4   Date            153 non-null    object
#  5   Low Price       153 non-null    int64
#  6   High Price      153 non-null    float64
#  7   Mostly Low      153 non-null    int64
#  8   Mostly High     153 non-null    float64
#  9   Origin          153 non-null    object
#  10  Item Size       153 non-null    object
#  11  Unit of Sale    24 non-null     object
#  12  Repack          153 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 15.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  153 non-null    object
#  1   City Name       153 non-null    object
#  2   Package         153 non-null    object
#  3   Variety         153 non-null    object
#  4   Date            153 non-null    object
#  5   Low Price       153 non-null    int64
#  6   High Price      153 non-null    float64
#  7   Mostly Low      153 non-null    int64
#  8   Mostly High     153 non-null    float64
#  9   Origin          153 non-null    object
#  10  Item Size       153 non-null    object
#  11  Unit of Sale    24 non-null     object
#  12  Repack          153 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 15.7+ KB

# %%
for col in Boston_df.columns:
    pct_missing = np.mean(Boston_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
Boston_df = Boston_df.drop(['Type', 'Sub Variety', 'Grade', 'Origin District', 'Color', 'Environment', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop', 'Trans Mode'], axis=1)

Boston_df['Variety'] = Boston_df['Variety'].fillna('_MISSING_')
Boston_df['Origin'] = Boston_df['Origin'].fillna('_MISSING_')
Boston_df['Item Size'] = Boston_df['Item Size'].fillna('_MISSING_')

Boston_df.info()

Boston_df.boxplot()

Boston_df['Item Size'].value_counts().plot.bar()

Boston_df.info()
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  352 non-null    object
#  1   City Name       352 non-null    object
#  2   Package         352 non-null    object
#  3   Variety         352 non-null    object
#  4   Date            352 non-null    object
#  5   Low Price       352 non-null    int64
#  6   High Price      352 non-null    int64
#  7   Mostly Low      352 non-null    int64
#  8   Mostly High     352 non-null    int64
#  9   Origin          352 non-null    object
#  10  Item Size       352 non-null    object
#  11  Unit of Sale    46 non-null     object
#  12  Repack          352 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 35.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  352 non-null    object
#  1   City Name       352 non-null    object
#  2   Package         352 non-null    object
#  3   Variety         352 non-null    object
#  4   Date            352 non-null    object
#  5   Low Price       352 non-null    int64
#  6   High Price      352 non-null    int64
#  7   Mostly Low      352 non-null    int64
#  8   Mostly High     352 non-null    int64
#  9   Origin          352 non-null    object
#  10  Item Size       352 non-null    object
#  11  Unit of Sale    46 non-null     object
#  12  Repack          352 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 35.9+ KB

# %%
for col in Newyork_df.columns:
    pct_missing = np.mean(Newyork_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
Newyork_df = Newyork_df.drop(['Type', 'Sub Variety', 'Grade', 'Origin District', 'Color', 'Environment', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop', 'Trans Mode'], axis=1)

Newyork_df['Variety'] = Newyork_df['Variety'].fillna('_MISSING_')
Newyork_df['Origin'] = Newyork_df['Origin'].fillna('_MISSING_')
Newyork_df['Item Size'] = Newyork_df['Item Size'].fillna('_MISSING_')

Newyork_df.info()

Newyork_df.boxplot()

Newyork_df['Item Size'].value_counts().plot.bar()

Newyork_df.info()
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  112 non-null    object
#  1   City Name       112 non-null    object
#  2   Package         112 non-null    object
#  3   Variety         112 non-null    object
#  4   Date            112 non-null    object
#  5   Low Price       112 non-null    int64
#  6   High Price      112 non-null    int64
#  7   Mostly Low      112 non-null    int64
#  8   Mostly High     112 non-null    int64
#  9   Origin          112 non-null    object
#  10  Item Size       112 non-null    object
#  11  Unit of Sale    25 non-null     object
#  12  Repack          112 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 11.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  112 non-null    object
#  1   City Name       112 non-null    object
#  2   Package         112 non-null    object
#  3   Variety         112 non-null    object
#  4   Date            112 non-null    object
#  5   Low Price       112 non-null    int64
#  6   High Price      112 non-null    int64
#  7   Mostly Low      112 non-null    int64
#  8   Mostly High     112 non-null    int64
#  9   Origin          112 non-null    object
#  10  Item Size       112 non-null    object
#  11  Unit of Sale    25 non-null     object
#  12  Repack          112 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 11.5+ KB

# %%
for col in Philadelphia_df.columns:
    pct_missing = np.mean(Philadelphia_df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
Philadelphia_df = Philadelphia_df.drop(['Type', 'Sub Variety', 'Grade', 'Origin District', 'Color', 'Environment', 'Quality', 'Condition', 'Appearance', 'Storage', 'Crop', 'Trans Mode'], axis=1)

Philadelphia_df['Variety'] = Philadelphia_df['Variety'].fillna('_MISSING_')
Philadelphia_df['Origin'] = Philadelphia_df['Origin'].fillna('_MISSING_')
Philadelphia_df['Item Size'] = Philadelphia_df['Item Size'].fillna('_MISSING_')

Philadelphia_df.info()

Philadelphia_df.boxplot()

Philadelphia_df['Item Size'].value_counts().plot.bar()

Philadelphia_df.info()
# Out:
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  57 non-null     object
#  1   City Name       57 non-null     object
#  2   Package         57 non-null     object
#  3   Variety         57 non-null     object
#  4   Date            57 non-null     object
#  5   Low Price       57 non-null     int64
#  6   High Price      57 non-null     int64
#  7   Mostly Low      57 non-null     int64
#  8   Mostly High     57 non-null     int64
#  9   Origin          57 non-null     object
#  10  Item Size       57 non-null     object
#  11  Unit of Sale    11 non-null     object
#  12  Repack          57 non-null     object
# dtypes: int64(4), object(9)
# memory usage: 5.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Commodity Name  57 non-null     object
#  1   City Name       57 non-null     object
#  2   Package         57 non-null     object
#  3   Variety         57 non-null     object
#  4   Date            57 non-null     object
#  5   Low Price       57 non-null     int64
#  6   High Price      57 non-null     int64
#  7   Mostly Low      57 non-null     int64
#  8   Mostly High     57 non-null     int64
#  9   Origin          57 non-null     object
#  10  Item Size       57 non-null     object
#  11  Unit of Sale    11 non-null     object
#  12  Repack          57 non-null     object
# dtypes: int64(4), object(9)
# memory usage: 5.9+ KB

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
Northeast_df = Baltimore_df.append([Boston_df, Newyork_df, Philadelphia_df])
Northeast_df
# Out:
# C:\Users\dance\AppData\Local\Temp\ipykernel_51832\3134932996.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Northeast_df = Baltimore_df.append([Boston_df, Newyork_df, Philadelphia_df])
#    Commodity Name     City Name             Package      Variety        Date  \
# 0        PUMPKINS     BALTIMORE        24 inch bins    _MISSING_  04/29/2017
# 1        PUMPKINS     BALTIMORE        24 inch bins    _MISSING_  05/06/2017
# 2        PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016
# 3        PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016
# 4        PUMPKINS     BALTIMORE        24 inch bins  HOWDEN TYPE  11/05/2016
# ..            ...           ...                 ...          ...         ...
# 52       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  11/05/2016
# 53       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  08/26/2017
# 54       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/16/2017
# 55       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/23/2017
# 56       PUMPKINS  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/30/2017
#
#     Low Price  High Price  Mostly Low  Mostly High     Origin  Item Size  \
# 0         270       280.0         270        280.0  _MISSING_        lge
# 1         270       280.0         270        280.0  _MISSING_        lge
# 2         160       160.0         160        160.0   DELAWARE        med
# 3         160       160.0         160        160.0   VIRGINIA        med
# 4          90       100.0          90        100.0   MARYLAND        lge
# ..        ...         ...         ...          ...        ...        ...
# 52         16        18.0          16         18.0       OHIO  _MISSING_
# 53         18        20.0          18         20.0   MICHIGAN  _MISSING_
# 54         16        16.0          16         16.0       OHIO  _MISSING_
# 55         15        16.0          15         16.0       OHIO  _MISSING_
# 56         15        18.0          15         18.0       OHIO  _MISSING_
#
#    Unit of Sale Repack
# 0           NaN      E
# 1           NaN      E
# 2           NaN      N
# 3           NaN      N
# 4           NaN      N
# ..          ...    ...
# 52   SHELLACKED      N
# 53   SHELLACKED      N
# 54   SHELLACKED      N
# 55   SHELLACKED      N
# 56   SHELLACKED      N
#
# [674 rows x 13 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
Northeast_df.groupby('Unit of Sale').agg({'Low Price': 'mean', 'High Price': 'mean'})
# Out:
#                Low Price  High Price
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety
Northeast_df.groupby('City Name').mean()
# Out:
#                Low Price  High Price  Mostly Low  Mostly High
# City Name
# BALTIMORE     101.490196  109.055556  101.490196   108.859477
# BOSTON        162.840909  187.235795  172.721591   176.130682
# NEW YORK      107.125000  116.482143  107.312500   116.410714
# PHILADELPHIA   98.140351  103.754386   98.491228   103.754386

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
